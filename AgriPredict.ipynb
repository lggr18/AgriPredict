# %% [markdown]
# ## Import python modules

# %%
from google.colab import drive
import pandas as pd

# %% [markdown]
# ## Download data

# %%
drive.mount('/content/drive')
agroclimatico1 = pd.read_csv('/content/drive/MyDrive/AgriPredict/Project/Agroclimaticos Canelones - Agroclimaticos Canelones.csv', header=0)
agroclimatico2= pd.read_csv('/content/drive/MyDrive/AgriPredict/Project/Agroclimaticos Colonia - Agroclimaticos Colonia.csv', header=0)
agroclimatico3= pd.read_csv('/content/drive/MyDrive/AgriPredict/Project/DatosDiariosConsulta (2) - DatosDiariosConsulta (2).csv', header=0)
agroclimatico1.columns = ['Canelones_' + col for col in agroclimatico1.columns]
agroclimatico2.columns = ['Colonia_' + col for col in agroclimatico2.columns]
agroclimatico3.columns = ['Salto_' + col for col in agroclimatico3.columns]
agroclimatico_data = pd.concat([agroclimatico1, agroclimatico2, agroclimatico3], axis=1)
agroclimatico_data = agroclimatico_data.drop('Colonia_Fecha', axis=1)
agroclimatico_data = agroclimatico_data.drop('Salto_Fecha', axis=1)
agroclimatico_data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   Canelones_Fecha  Canelones_Heliofanía (Hrs.)  \
# 0      2007-01-01                         13.5
# 1      2007-01-02                          5.3
# 2      2007-01-03                          5.2
# 3      2007-01-04                          7.2
# 4      2007-01-05                          9.4
#
#    Canelones_Precip. Acumulada (mm)  Canelones_Heliofanía Relativa (%)  \
# 0                               0.0                               94.6
# 1                              31.0                               37.2
# 2                               0.0                               36.5
# 3                               0.0                               50.6
# 4                               0.0                               66.1
#
#    Canelones_Rad.Solar (xHelio)cal/cm²  Canelones_Precip. Efectiva (mm)  \
# ...

# %%
data = pd.read_csv('/content/drive/MyDrive/AgriPredict/Project/Agroclimaticos Canelones - Agroclimaticos Canelones.csv', header=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fecha'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-da7e6dd833d0> in <cell line: 0>()
# ----> 1 agroclimatico['Fecha'] = pd.to_datetime(agroclimatico['Fecha'])
#
# ...
